# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/projects/Finaldraft-FICS-PCB.zip -d /content/
# %cd /content/
# Out:
# /content

# %%
# !pip install -q torch torchvision albumentations scikit-learn opencv-python
# !pip install -q segmentation-models-pytorch
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 122.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 3.6 MB/s eta 0:00:00

# %%
# %cd /content/Finaldraft-FICS-PCB/
# Out:
# /content/Finaldraft-FICS-PCB

# %%
# %cd /content/Finaldraft-FICS-PCB
# !mkdir -p outputs
# !ls
# Out:
# /content/Finaldraft-FICS-PCB
# augmentation.py  models      __pycache__       train.py
# data		 network.py  README.md	       visualize.py
# eval.py		 outputs     requirements.txt

# %%
# from inside /content/project_root
# !python train.py \
  --model unet \
  --data-dir data \
  --output-dir /content/Finaldraft-FICS-PCB/outputs \
  --img-size 640 \
  --batch-size 8 \
  --epochs 80 \
  --lr 1e-4 \
  --patience 20
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/80 - Train Loss: 0.9795 | Val Loss: 0.9336
# ✔️ Best model saved at epoch 1
# Epoch 2/80 - Train Loss: 0.8686 | Val Loss: 0.9874
# Epoch 3/80 - Train Loss: 0.8456 | Val Loss: 0.7458
# ✔️ Best model saved at epoch 3
# Epoch 4/80 - Train Loss: 0.7921 | Val Loss: 0.7160
# ✔️ Best model saved at epoch 4
# Epoch 5/80 - Train Loss: 0.7696 | Val Loss: 0.7009
# ✔️ Best model saved at epoch 5
# Epoch 6/80 - Train Loss: 0.7428 | Val Loss: 0.6502
# ✔️ Best model saved at epoch 6
# Epoch 7/80 - Train Loss: 0.7275 | Val Loss: 0.8294
# Epoch 8/80 - Train Loss: 0.7122 | Val Loss: 0.7129
# Epoch 9/80 - Train Loss: 0.6957 | Val Loss: 0.5960
# ✔️ Best model saved at epoch 9
# Epoch 10/80 - Train Loss: 0.6822 | Val Loss: 0.6324
# ...

# %%
# from inside /content/project_root
# !python train.py \
  --model unet_vgg16 \
  --data-dir data \
  --output-dir /content/Finaldraft-FICS-PCB/outputs \
  --img-size 640 \
  --batch-size 8 \
  --epochs 80 \
  --lr 1e-4 \
  --patience 20
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch 1/80 - Train Loss: 0.9855 | Val Loss: 0.8494
# ✔️ Best model saved at epoch 1
# Epoch 2/80 - Train Loss: 0.8876 | Val Loss: 0.8534
# Epoch 3/80 - Train Loss: 0.8588 | Val Loss: 0.8036
# ✔️ Best model saved at epoch 3
# ...

# %%
# from inside /content/project_root
# !python train.py \
  --model attunet \
  --data-dir data \
  --output-dir /content/Finaldraft-FICS-PCB/outputs \
  --img-size 640 \
  --batch-size 8 \
  --epochs 80 \
  --lr 1e-4 \
  --patience 20
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/80 - Train Loss: 0.9531 | Val Loss: 0.8374
# ✔️ Best model saved at epoch 1
# Epoch 2/80 - Train Loss: 0.8589 | Val Loss: 1.1099
# Epoch 3/80 - Train Loss: 0.8085 | Val Loss: 0.7491
# ✔️ Best model saved at epoch 3
# Epoch 4/80 - Train Loss: 0.7947 | Val Loss: 0.7105
# ✔️ Best model saved at epoch 4
# Epoch 5/80 - Train Loss: 0.7798 | Val Loss: 0.7710
# Epoch 6/80 - Train Loss: 0.7651 | Val Loss: 0.6820
# ✔️ Best model saved at epoch 6
# Epoch 7/80 - Train Loss: 0.7189 | Val Loss: 0.6599
# ✔️ Best model saved at epoch 7
# Epoch 8/80 - Train Loss: 0.7316 | Val Loss: 0.6376
# ✔️ Best model saved at epoch 8
# Epoch 9/80 - Train Loss: 0.7144 | Val Loss: 0.6750
# Epoch 10/80 - Train Loss: 0.7294 | Val Loss: 0.6561
# ...

# %%
# from inside /content/project_root
# !python train.py \
  --model deeplabv3plus_resnet34\
  --data-dir data \
  --output-dir /content/Finaldraft-FICS-PCB/outputs \
  --img-size 640 \
  --batch-size 8 \
  --epochs 80 \
  --lr 1e-4 \
  --patience 20
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# config.json: 100% 156/156 [00:00<00:00, 814kB/s]
# model.safetensors: 100% 87.3M/87.3M [00:00<00:00, 194MB/s]
# Epoch 1/80 - Train Loss: 0.7790 | Val Loss: 0.6181
# ✔️ Best model saved at epoch 1
# Epoch 2/80 - Train Loss: 0.5068 | Val Loss: 0.4488
# ✔️ Best model saved at epoch 2
# Epoch 3/80 - Train Loss: 0.4088 | Val Loss: 0.3652
# ✔️ Best model saved at epoch 3
# Epoch 4/80 - Train Loss: 0.3457 | Val Loss: 0.3045
# ✔️ Best model saved at epoch 4
# Epoch 5/80 - Train Loss: 0.2855 | Val Loss: 0.2700
# ✔️ Best model saved at epoch 5
# Epoch 6/80 - Train Loss: 0.2797 | Val Loss: 0.2811
# Epoch 7/80 - Train Loss: 0.2474 | Val Loss: 0.3182
# Epoch 8/80 - Train Loss: 0.2323 | Val Loss: 0.2731
# Epoch 9/80 - Train Loss: 0.2230 | Val Loss: 0.2616
# ...

# %%
# from inside /content/project_root
# !python train.py \
  --model deeplabv3plus_mit_b0\
  --data-dir data \
  --output-dir /content/Finaldraft-FICS-PCB/outputs \
  --img-size 640 \
  --batch-size 8 \
  --epochs 80 \
  --lr 1e-4 \
  --patience 20
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# config.json: 100% 135/135 [00:00<00:00, 853kB/s]
# model.safetensors: 100% 14.3M/14.3M [00:00<00:00, 58.0MB/s]
# Epoch 1/80 - Train Loss: 0.8907 | Val Loss: 0.6664
# ✔️ Best model saved at epoch 1
# Epoch 2/80 - Train Loss: 0.6302 | Val Loss: 0.5335
# ✔️ Best model saved at epoch 2
# Epoch 3/80 - Train Loss: 0.5048 | Val Loss: 0.4599
# ✔️ Best model saved at epoch 3
# Epoch 4/80 - Train Loss: 0.4215 | Val Loss: 0.4007
# ✔️ Best model saved at epoch 4
# Epoch 5/80 - Train Loss: 0.4104 | Val Loss: 0.4150
# Epoch 6/80 - Train Loss: 0.3543 | Val Loss: 0.3818
# ✔️ Best model saved at epoch 6
# Epoch 7/80 - Train Loss: 0.2972 | Val Loss: 0.2991
# ✔️ Best model saved at epoch 7
# Epoch 8/80 - Train Loss: 0.2886 | Val Loss: 0.3274
# ...

# %%
# from inside /content/project_root
# !python train.py \
  --model unet_mobilenet \
  --data-dir data \
  --output-dir /content/Finaldraft-FICS-PCB/outputs \
  --img-size 640 \
  --batch-size 8 \
  --epochs 80 \
  --lr 1e-4 \
  --patience 20
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/80 - Train Loss: 1.0102 | Val Loss: 0.9936
# ✔️ Best model saved at epoch 1
# Epoch 2/80 - Train Loss: 0.9099 | Val Loss: 0.8385
# ✔️ Best model saved at epoch 2
# Epoch 3/80 - Train Loss: 0.8334 | Val Loss: 0.8210
# ✔️ Best model saved at epoch 3
# Epoch 4/80 - Train Loss: 0.8154 | Val Loss: 0.8829
# Epoch 5/80 - Train Loss: 0.7752 | Val Loss: 0.8679
# Epoch 6/80 - Train Loss: 0.7791 | Val Loss: 0.9519
# Epoch 7/80 - Train Loss: 0.7379 | Val Loss: 0.6597
# ✔️ Best model saved at epoch 7
# Epoch 8/80 - Train Loss: 0.7434 | Val Loss: 0.6883
# Epoch 9/80 - Train Loss: 0.7185 | Val Loss: 0.6858
# Epoch 10/80 - Train Loss: 0.7148 | Val Loss: 0.6560
# ✔️ Best model saved at epoch 10
# Epoch 11/80 - Train Loss: 0.6956 | Val Loss: 0.6433
# ...

# %%
# from inside /content/project_root
# !python train.py \
  --model resunet \
  --data-dir data \
  --output-dir /content/Finaldraft-FICS-PCB/outputs \
  --img-size 640 \
  --batch-size 8 \
  --epochs 80 \
  --lr 1e-4 \
  --patience 20
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/80 - Train Loss: 0.8682 | Val Loss: 0.6670
# ✔️ Best model saved at epoch 1
# Epoch 2/80 - Train Loss: 0.7866 | Val Loss: 0.6750
# Epoch 3/80 - Train Loss: 0.7569 | Val Loss: 0.6720
# Epoch 4/80 - Train Loss: 0.7397 | Val Loss: 0.6324
# ✔️ Best model saved at epoch 4
# Epoch 5/80 - Train Loss: 0.7321 | Val Loss: 0.6645
# Epoch 6/80 - Train Loss: 0.6814 | Val Loss: 0.6357
# Epoch 7/80 - Train Loss: 0.7032 | Val Loss: 0.7001
# Epoch 8/80 - Train Loss: 0.6737 | Val Loss: 0.6614
# Epoch 9/80 - Train Loss: 0.6908 | Val Loss: 0.6278
# ✔️ Best model saved at epoch 9
# Epoch 10/80 - Train Loss: 0.6666 | Val Loss: 0.6091
# ✔️ Best model saved at epoch 10
# Epoch 11/80 - Train Loss: 0.6603 | Val Loss: 0.5862
# ✔️ Best model saved at epoch 11
# ...

# %%
# from inside /content/project_root
# !python train.py \
  --model unetpp \
  --data-dir data \
  --output-dir /content/Finaldraft-FICS-PCB/outputs \
  --img-size 640 \
  --batch-size 8 \
  --epochs 80 \
  --lr 1e-4 \
  --patience 20
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/80 - Train Loss: 0.9374 | Val Loss: 0.7744
# ✔️ Best model saved at epoch 1
# Epoch 2/80 - Train Loss: 0.8654 | Val Loss: 0.7670
# ✔️ Best model saved at epoch 2
# Epoch 3/80 - Train Loss: 0.8157 | Val Loss: 0.7497
# ✔️ Best model saved at epoch 3
# Epoch 4/80 - Train Loss: 0.7703 | Val Loss: 0.7371
# ✔️ Best model saved at epoch 4
# Epoch 5/80 - Train Loss: 0.7594 | Val Loss: 0.6890
# ✔️ Best model saved at epoch 5
# Epoch 6/80 - Train Loss: 0.7327 | Val Loss: 0.7107
# Epoch 7/80 - Train Loss: 0.6997 | Val Loss: 0.6431
# ✔️ Best model saved at epoch 7
# Epoch 8/80 - Train Loss: 0.6717 | Val Loss: 0.6175
# ✔️ Best model saved at epoch 8
# Epoch 9/80 - Train Loss: 0.6820 | Val Loss: 0.6811
# Epoch 10/80 - Train Loss: 0.6544 | Val Loss: 0.6272
# ...

# %%
# from inside /content/project_root
# !python train.py \
  --model unet3plus \
  --data-dir data \
  --output-dir /content/Finaldraft-FICS-PCB/outputs \
  --img-size 640 \
  --batch-size 2 \
  --epochs 100 \
  --lr 1e-4 \
  --patience 20
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/100 - Train Loss: 0.9327 | Val Loss: 0.8395
# ✔️ Best model saved at epoch 1
# Epoch 2/100 - Train Loss: 0.8987 | Val Loss: 0.8457
# Epoch 3/100 - Train Loss: 0.8708 | Val Loss: 0.8588
# Epoch 4/100 - Train Loss: 0.8751 | Val Loss: 0.8139
# ✔️ Best model saved at epoch 4
# Epoch 5/100 - Train Loss: 0.8519 | Val Loss: 0.8373
# Epoch 6/100 - Train Loss: 0.8593 | Val Loss: 0.8066
# ✔️ Best model saved at epoch 6
# Epoch 7/100 - Train Loss: 0.8457 | Val Loss: 0.8443
# Epoch 8/100 - Train Loss: 0.8399 | Val Loss: 0.8052
# ✔️ Best model saved at epoch 8
# Epoch 9/100 - Train Loss: 0.8361 | Val Loss: 0.7851
# ✔️ Best model saved at epoch 9
# Epoch 10/100 - Train Loss: 0.8406 | Val Loss: 0.7865
# Epoch 11/100 - Train Loss: 0.8327 | Val Loss: 0.7830
# ...

# %%
import shutil
shutil.make_archive('/content/Finaldraft-FICS-PCB', 'zip', '/content/Finaldraft-FICS-PCB')
# Out:
# '/content/Finaldraft.zip'

# %%
from google.colab import files
files.download('/content/Finaldraft-FICS-PCB')

# %%
while True:pass

# %%
# from inside /content/project_root
# !python train.py \
  --model bisenetmulticlass \
  --data-dir data \
  --output-dir /content/Finaldraft-FICS-PCB/outputs \
  --img-size 640 \
  --batch-size 8 \
  --epochs 80 \
  --lr 1e-4 \
  --patience 10
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/80 - Train Loss: 0.9075 | Val Loss: 0.7906
# ✔️ Best model saved at epoch 1
# Epoch 2/80 - Train Loss: 0.7833 | Val Loss: 0.7620
# ✔️ Best model saved at epoch 2
# Epoch 3/80 - Train Loss: 0.7322 | Val Loss: 0.6159
# ✔️ Best model saved at epoch 3
# Epoch 4/80 - Train Loss: 0.6946 | Val Loss: 0.6266
# Epoch 5/80 - Train Loss: 0.6694 | Val Loss: 0.5541
# ✔️ Best model saved at epoch 5
# Epoch 6/80 - Train Loss: 0.6372 | Val Loss: 0.6201
# Epoch 7/80 - Train Loss: 0.6366 | Val Loss: 0.6354
# Epoch 8/80 - Train Loss: 0.6297 | Val Loss: 0.5654
# Epoch 9/80 - Train Loss: 0.5926 | Val Loss: 0.5382
# ✔️ Best model saved at epoch 9
# Epoch 10/80 - Train Loss: 0.5728 | Val Loss: 0.4929
# ✔️ Best model saved at epoch 10
# ...

# %%
# from inside /content/project_root
# !python train.py \
  --model stdc \
  --data-dir data \
  --output-dir /content/Finaldraft-FICS-PCB/outputs \
  --img-size 640 \
  --batch-size 8 \
  --epochs 80 \
  --lr 1e-4 \
  --patience 10
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/80 - Train Loss: 0.8882 | Val Loss: 0.7646
# ✔️ Best model saved at epoch 1
# Epoch 2/80 - Train Loss: 0.7879 | Val Loss: 0.7371
# ✔️ Best model saved at epoch 2
# Epoch 3/80 - Train Loss: 0.7281 | Val Loss: 0.6384
# ✔️ Best model saved at epoch 3
# Epoch 4/80 - Train Loss: 0.6943 | Val Loss: 0.6417
# Epoch 5/80 - Train Loss: 0.6801 | Val Loss: 0.5868
# ✔️ Best model saved at epoch 5
# Epoch 6/80 - Train Loss: 0.6558 | Val Loss: 0.5908
# Epoch 7/80 - Train Loss: 0.6361 | Val Loss: 0.6958
# Epoch 8/80 - Train Loss: 0.6148 | Val Loss: 0.5326
# ✔️ Best model saved at epoch 8
# Epoch 9/80 - Train Loss: 0.6302 | Val Loss: 0.5690
# Epoch 10/80 - Train Loss: 0.6075 | Val Loss: 0.5327
# Epoch 11/80 - Train Loss: 0.5841 | Val Loss: 0.5714
# ...

# %%
# from inside /content/project_root
# !python train.py \
  --model ddrnet \
  --data-dir data \
  --output-dir /content/Finaldraft-FICS-PCB/outputs \
  --img-size 640 \
  --batch-size 8 \
  --epochs 80 \
  --lr 1e-4 \
  --patience 10
# Out:
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:111: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/80 - Train Loss: 0.9640 | Val Loss: 0.9907
# ✔️ Best model saved at epoch 1
# Epoch 2/80 - Train Loss: 0.8472 | Val Loss: 0.7639
# ✔️ Best model saved at epoch 2
# Epoch 3/80 - Train Loss: 0.7866 | Val Loss: 0.7336
# ✔️ Best model saved at epoch 3
# Epoch 4/80 - Train Loss: 0.7918 | Val Loss: 0.6717
# ✔️ Best model saved at epoch 4
# Epoch 5/80 - Train Loss: 0.7363 | Val Loss: 0.6497
# ✔️ Best model saved at epoch 5
# Epoch 6/80 - Train Loss: 0.7106 | Val Loss: 0.6047
# ✔️ Best model saved at epoch 6
# Epoch 7/80 - Train Loss: 0.7169 | Val Loss: 0.6223
# Epoch 8/80 - Train Loss: 0.6622 | Val Loss: 0.6446
# Epoch 9/80 - Train Loss: 0.6612 | Val Loss: 0.5707
# ✔️ Best model saved at epoch 9
# Epoch 10/80 - Train Loss: 0.6297 | Val Loss: 0.6050
# ...

# %%
import shutil
shutil.rmtree('/content/Finaldraft-FICS-PCB/outputs/bisenetmulticlass')
